# %%
# !pwd
# Out:
# /home/cse-lab/Desktop/B191112

# %%
# !ls
# Out:
# B191112.csv  b191112pandas.ipynb

# %%
import pandas as pd
df = pd.read_csv("B191112.csv")
df.head(50)
# Out:
#                Suburb             Address  Rooms Type      Price Method  \
# 0          Abbotsford       49 Lithgow St      3    h  1490000.0      S
# 1          Abbotsford       59A Turner St      3    h  1220000.0      S
# 2          Abbotsford       119B Yarra St      3    h  1420000.0      S
# 3          Aberfeldie          68 Vida St      3    h  1515000.0      S
# 4        Airport West    92 Clydesdale Rd      2    h   670000.0      S
# 5        Airport West        4/32 Earl St      2    t   530000.0      S
# 6        Airport West      3/74 Hawker St      2    u   540000.0      S
# 7        Airport West   1/26 Highridge Cr      3    h   715000.0     SP
# 8           Albanvale       1 Jackson Cct      6    h        NaN     PI
# 9         Albert Park         18 Mills St      3    h  1925000.0      S
# 10             Albion  3/15 Drummartin St      3    u   515000.0      S
# 11             Albion      3A Kororoit St      4    h   717000.0      S
# ...

# %%
df.tail()
# Out:
# 63016    2
# 63017    3
# 63018    3
# 63019    3
# 63020    3
# Name: Rooms, dtype: int64

# %%
print(df.shape)
# Out:
# (63023, 13)

# %%
df=df.dropna()
print(df.dropna)
# Out:
# <bound method Series.dropna of 0        3
# 1        3
# 2        3
# 3        3
# 4        2
#         ..
# 63016    2
# 63017    3
# 63018    3
# 63019    3
# 63020    3
# Name: Rooms, Length: 48433, dtype: int64>

# %%
rooms=df["Rooms"]
print(rooms)
# Out:
# 0        3
# 1        3
# 2        3
# 3        3
# 4        2
#         ..
# 63018    3
# 63019    3
# 63020    3
# 63021    3
# 63022    4
# Name: Rooms, Length: 63023, dtype: int64

# %%
price = list(df["Price"])
import matplotlib.pyplot as plt


fig = plt.figure()
plt.hist(x = price,bins=40,edgecolor="red")
plt.xlabel("price range")
plt.ylabel("No. of houses")
plt.title("Histogram of prices")
plt.show()

rooms_count=df["Rooms"].value_counts()
rooms_count=dict(rooms_count)
print(rooms_count)

a=rooms_count.keys()#room_size
b=rooms_count.values()#no_of_rooms
# Out:
# {3: 27950, 4: 15747, 2: 13248, 5: 3434, 1: 2111, 6: 424, 7: 61, 8: 29, 10: 7, 9: 5, 12: 4, 31: 1, 16: 1, 11: 1}

# %%
#piechat

fig=plt.figure(figsize=(6,6))

plt.pie(x=b,labels=a)
plt.title("Piechat")
plt.legend()
plt.show()

# %%
#barplot

type_countdf["Type"].value_counts()
# Out:
# h    45053
# u    11655
# t     6315
# Name: Type, dtype: int64

# %%
price = list(df["Type"])
#import matplotlib.pyplot as plt

fig = plt.figure()
plt.hist(x = price,bins=5,edgecolor="blue")
plt.xlabel("price range")
plt.ylabel("No. of houses")
plt.title("Bargraph of prices")
plt.show()

# %%
#Scatter plot

price=df["Price"]
price=list(price)

distance=df["Distance"]
distance=list(distance)

fig = plt.figure()

#lineplot

plt.plot(distance,price,linestyle="-", marker="o")

plt.show()
